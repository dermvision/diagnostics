# %% [markdown]
# #Data to Taxonomy Pipeline

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from string import join, lowercase, uppercase

# %% [markdown]
# ###Useful Functions

# %%
def taxonomy_from_paths(P):
    
    T = {}
    for p in P:
        t = T
        for k in p:
            if k not in t.keys(): t[k] = {}
            t = t[k]
            
    return T

# %%
def paths_from_taxonomy(T):
    
    def f(T, p=[]):
        if T == {}:
            P.append(p)
        else:
            for k in sorted(T.keys()):
                f(T[k], p+[k])
    
    P = []
    f(T)
    
    return P

# %%
def read_taxonomy(f):

    with open(f, 'rb') as file:
        P = [[k.split('-') for k in p.split('/')] 
             for p in file.readlines()]
    
    fix = lambda k: filter(lambda c: c in lowercase, k.lower())
    P = [[join(map(fix, k), '-') for k in p] for p in P]
    
    return P

# %% [markdown]
# ###Clean Taxonomy

# %%
def remove_leaves(T):
    for k in T.keys():
        if T[k] == {}: 
            del T[k]
        else:
            remove_leaves(T[k])

# %%
with open('taxonomy_messy.txt', 'rb') as file: P = file.readlines()
P = filter(lambda s: all(c not in uppercase for c in s), P)
P = [[k.split('-') for k in p.split('/')] for p in P]
fix = lambda s: filter(lambda c: c in lowercase, s.lower())
P = [[join(map(fix, k), '-') for k in p] for p in P]
T = taxonomy_from_paths(P)
remove_leaves(T)
P = paths_from_taxonomy(T)
with open('taxonomy.txt', 'wb') as file:
    for p in P: file.write('{}\n'.format(join(p,'/')))

# %% [markdown]
# ###Sanity Check

# %%
P = read_taxonomy('taxonomy.txt')
P == paths_from_taxonomy(taxonomy_from_paths(P))
# Out:
# True

# %% [markdown]
# ###Read Labels

# %%
with open('visualdx/labels.txt') as file:
    labels = [label.split('|')[1].split() for label in file.readlines()]

# %%
fix = lambda s: filter(lambda c: c in string.lowercase, s.lower())
labels = [map(fix, label) for label in labels]

# %%
sorted(set([string.join(label, ' ') for label in labels]))
# Out:
# ['abscess',
#  'abscess of the newborn',
#  'acanthoma epidermolytic',
#  'acanthoma large cell',
#  'acanthosis nigricans',
#  'accessory tragus',
#  'acne conglobata',
#  'acne excorie',
#  'acne fulminans',
#  'acne infantile',
#  'acne keloidalis nuchae',
#  'acne neonatal',
#  'acne steroid',
#  'acne vulgaris',
#  'acquired acrodermatitis enteropathica',
#  'acral erythema',
#  'acroangiodermatitis',
#  'acrochordon',
#  'acrokeratoelastoidosis',
#  'acrokeratosis paraneoplastica',
#  'acrokeratosis verruciformis',
#  'acroosteolysis',
#  'acropustulosis of infancy',
#  'actinic keratosis',
#  'actinic prurigo',
#  'actinomycosis',
#  'acute generalized exanthematous pustulosis',
#  'acute hemorrhagic edema of infancy',
#  'acute myelomonocytic leukemia',
#  'adamsoliver syndrome',
#  'addison disease',
#  'adiposis dolorosa',
#  'adrenogenital syndrome',
#  'adult mastocytosis',
#  'adultonset stills disease',
#  'aflatoxicosis',
#  'african tick bite fever',
#  'africanized bee sting',
#  'ainhum',
#  'albinism',
#  'alopecia areata',
#  'alopecia drug induced',
#  'alopecia female pattern',
#  'alopecia male pattern',
#  'alopecia mucinosa',
#  'alopecia traction',
#  'alstrom syndrome',
#  'alternariosis',
#  'amalgam tattoo',
#  'amebiasis',
#  'amniotic band syndrome',
#  'amyloidosis primary systemic',
#  'anetoderma',
#  'anetoderma of prematurity',
#  'angioedema',
#  'angioedema hereditary',
#  'angioendotheliomatosis',
#  'angiofibroma',
#  'angiokeratoma circumscriptum',
#  'angiokeratoma of mibelli',
#  'angiokeratoma of scrotum',
#  'angiolipoma',
#  'angiolymphoid hyperplasia with eosinophilia',
#  'angioma serpiginosum',
#  'angiosarcoma',
#  'anhidrotic ectodermal dysplasia',
#  'anisakiasis',
#  'annular erythema of infancy',
#  'anonychia congenital',
#  'anthrax cutaneous',
#  'anthrax inhalational',
#  'antiphospholipid antibody syndrome',
#  'apert syndrome',
#  'aphthous stomatitis',
#  'aplasia cutis congenita',
#  'apocrine hidrocystoma',
#  'argentine hemorrhagic fever',
#  'argyria',
#  'arsenic poisoning',
#  'arsenical keratosis',
#  'arteriovenous malformations',
#  'artificial nail damage',
#  'aspergillosis',
#  'aspergillosis primary cutaneous of premature infants',
#  'asymmetric periflexural exanthem of childhood',
#  'atrainduced scrotal ulcer',
#  'atrial myxoma',
#  'atrichia congenita',
#  'atrophoderma',
#  'atrophy steroid',
#  'atypical fibroxanthoma',
#  'atypical measles',
#  'atypical mycobacterial infection',
#  'atypical nevus syndrome',
#  'autoeczematization',
#  'autoerythrocyte sensitization',
#  'autoimmune progesterone dermatitis',
#  'avian influenza hn',
#  'axillary granular parakeratosis',
#  'bacillary angiomatosis',
#  'balanitis nonspecific',
#  'bartonellosis',
#  'basal cell carcinoma infiltrating morpheaform',
#  'basal cell carcinoma nodular',
#  'basal cell carcinoma pigmented',
#  'basal cell carcinoma superficial',
#  'basal cell nevus syndrome',
#  'beaus lines',
#  'bedbug bite',
#  'behets syndrome',
#  'benign cephalic histiocytosis',
#  'bisphosphonaterelated osteonecrosis of the jaw',
#  'bite or sting arthropod',
#  'bite or sting arthropod pediatric',
#  'bite spider',
#  'blastomycosis',
#  'blistering distal dactylitis',
#  'blue rubber bleb nevus syndrome',
#  'bluegray spot',
#  'botryomycosis',
#  'bowelbypass syndrome',
#  'bowenoid papulosis',
#  'bowens disease',
#  'brachyonychia hereditary',
#  'branchial cleft cyst or sinus',
#  'breast engorgement physiologic of newborn',
#  'bromoderma',
#  'bronze baby syndrome',
#  'brucellosis',
#  'buergers disease',
#  'bullosis diabeticorum',
#  'bullous congenital ichthyosiform erythroderma',
#  'bullous dermatosis of childhood',
#  'bullous hemorrhagic dermatosis',
#  'bullous pemphigoid',
#  'bullous pemphigoid of childhood',
#  'bumblebee sting',
#  'burn thermal or electrical',
#  'burns of oral mucosa',
#  'buruli ulcer',
#  'buschkeollendorff syndrome',
#  'caf au lait macule',
#  'calcified nodule subepidermal',
#  'calcinosis cutis',
#  'calciphylaxis',
#  'callus',
#  'campylobacter infections',
#  'camrsa skin infection',
#  'candidiasis',
#  'candidiasis chronic mucocutaneous',
#  'candidiasis congenital',
#  'candidiasis diaper dermatitis',
#  'candidiasis male genital',
#  'candidiasis nails',
#  'candidiasis neonatal',
#  'candidiasis oral',
#  'candidiasis vulvovaginal',
#  'capillaritis',
#  'carbuncle',
#  'carcinoid syndrome',
#  'carcinoma metastatic',
#  'carney complex',
#  'carotenemia',
#  'cataracts',
#  'catscratch disease',
#  'cauliflower ear',
#  'cellulitis',
#  'centipede envenoming',
#  'central centrifugal cicatricial alopecia',
#  'cephalohematoma',
#  'chancroid',
#  'chediakhigashi syndrome',
#  'cheek chewing chronic',
#  'cheilitis',
#  'cheilitis actinic',
#  'cheilitis angular',
#  'chemotherapy induced mucositis',
#  'cherry hemangioma',
#  'chigger bite',
#  'chikungunya',
#  'chilblains',
#  'child abuse physical',
#  'child syndrome',
#  'chime syndrome',
#  'cholera',
#  'chondrodermatitis nodularis helicis',
#  'chondroid syringoma',
#  'chromhidrosis',
#  'chromoblastomycosis',
#  'chronic actinic dermatitis',
#  'chronic eczematous eruptions of the aged',
#  'chronic granulomatous disease',
#  'chronic lymphocytic leukemia',
#  'churgstrauss syndrome',
#  'cicatricial pemphigoid',
#  'clear cell acanthoma',
#  'clubbing of nails',
#  'cocaine levamisole toxicity',
#  'coccidioidomycosis',
#  'cockayne syndrome',
#  'cold panniculitis',
#  'cold urticaria',
#  'collodion baby',
#  'colloid milium',
#  'colorado tick fever',
#  'condyloma acuminatum',
#  'confluent and reticulated papillomatosis',
#  'congenital agammaglobulinemia',
#  'congenital erosive and vesicular dermatosis',
#  'congenital fanconi syndrome',
#  'congenital nevus giant',
#  'connective tissue nevi',
#  'conradis disease',
#  'coral snake envenoming',
#  'corn',
#  'corneal deposits drug induced',
#  'cornelia de lange syndrome',
#  'coumadin necrosis',
#  'cowdens disease',
#  'cowpox',
#  'crest syndrome',
#  'crimeancongo hemorrhagic fever',
#  'crohns disease',
#  'crouzon syndrome',
#  'cryofibrinogenemia',
#  'cryoglobulinemia',
#  'cryptococcosis',
#  'cushing syndrome',
#  'cutaneous cartilaginous rest',
#  'cutaneous diphtheria',
#  'cutaneous endometriosis',
#  'cutaneous horn',
#  'cutaneous tcell lymphoma',
#  'cutis laxa',
#  'cutis marmorata',
#  'cutis marmorata telangiectatica congenita',
#  'cutis rhomboidalis nuchae',
#  'cyclosporiasis',
#  'cyst epidermoid',
#  'cyst lymphoepithelial',
#  'cyst palatal and gingival of newborn',
#  'cystic hygroma',
#  'cysticercosis',
#  'cytomegalovirus infection',
#  'cytomegalovirus infection newborn',
#  'dariers disease',
#  'deep vein thrombosis',
#  'delusions of parasitosis',
#  'dengue fever',
#  'dengue hemorrhagic fever',
#  'dental sinus tract cutaneous',
#  'dental sinus tract mucosal',
#  'dermal sinus tract',
#  'dermatitis allergic contact',
#  'dermatitis allergic contact pediatric',
#  'dermatitis atopic',
#  'dermatitis caterpillar',
#  'dermatitis diaper irritant contact',
#  'dermatitis dyshidrotic',
#  'dermatitis exfoliative',
#  'dermatitis factitial',
#  'dermatitis granulomatous',
#  'dermatitis herpetiformis',
#  'dermatitis hogweed',
#  'dermatitis irritant contact',
#  'dermatitis liplicking',
#  'dermatitis nipple',
#  'dermatitis nummular',
#  'dermatitis of nail folds',
#  'dermatitis perioral',
#  'dermatitis perioral of childhood',
#  'dermatitis poison ivy  oak  sumac',
#  'dermatitis seborrheic',
#  'dermatitis stasis',
#  'dermatofibroma',
#  'dermatofibrosarcoma protuberans',
#  'dermatomyositis',
#  'dermatomyositis juvenile',
#  'dermatosis neglecta',
#  'dermatosis papulosa nigra',
#  'dermographism',
#  'dermoid cyst',
#  'diabetic dermopathy',
#  'digeorge syndrome',
#  'dissecting cellulitis of scalp',
#  'disseminated candidiasis',
#  'disseminated gonorrhea',
#  'disseminated granuloma annulare',
#  'disseminated intravascular coagulation',
#  'disseminated superficial actinic porokeratosis',
#  'drug eruption bullous',
#  'drug eruption exanthematous',
#  'drug eruption fixed',
#  'drug eruption general overview',
#  'drug eruption lichenoid',
#  'drug hypersensitivity syndrome',
#  'drug induced erythroderma',
#  'drug induced hypopigmentation',
#  'drug induced nail pigment',
#  'drug induced nonpalpable purpura',
#  'drug induced oral pigmentation',
#  'drug induced oral ulcer',
#  'drug induced photoallergic reaction',
#  'drug induced photosensitive reaction',
#  'drug induced phototoxic reaction',
#  'drug induced pigmentation amiodarone',
#  'drug induced pigmentation flagellate',
#  'drug induced pigmentation minocycline',
#  'drug induced skin ulcers',
#  'drug induced systemic contact dermatitis',
#  'druginduced pigmentation',
#  'dupuytrens contracture',
#  'dyskeratosis congenita',
#  'earlobe torn',
#  'ebola',
#  'eccrine gland carcinoma',
#  'eccrine hidradenitis palmarplantar',
#  'eccrine poroma',
#  'eccrine spiradenoma',
#  'ecthyma',
#  'ecthyma gangrenosum',
#  'ectodermal dysplasia',
#  'eczema craquele',
#  'eczema herpeticum',
#  'ehlersdanlos syndrome',
#  'ehrlichiosis',
#  'elastosis perforans serpiginosa',
#  'elephantiasis nostra verrucosa',
#  'emboli cholesterol',
#  'emboli fat',
#  'encephalocele',
#  'endocarditis subacute bacterial',
#  'enterohemorrhagic escherichia coli',
#  'enteroviral infection',
#  'eosinophilic cellulitis',
#  'eosinophilic fasciitis',
#  'eosinophilic folliculitis',
#  'eosinophilic pustular folliculitis in infancy',
#  'ephelides',
#  'epidermal nevus',
#  'epidermodysplasia verruciformis',
#  'epidermolysis bullosa acquisita',
#  'epidermolysis bullosa dystrophic',
#  'epidermolysis bullosa junctional',
#  'epidermolysis bullosa simplex',
#  'epidermolysis bullosa simplex dowlingmeara',
#  'ergotism',
#  'eruptive vellus hair cyst',
#  'erysipelas',
#  'erythema ab igne',
#  'erythema annulare centrifugum',
#  'erythema dyschromicum perstans',
#  'erythema elevatum diutinum',
#  'erythema gyratum repens',
#  'erythema induratum',
#  'erythema infectiosum',
#  'erythema marginatum',
#  'erythema multiforme',
#  'erythema nodosum',
#  'erythema toxicum neonatorum',
#  'erythrasma',
#  'erythrokeratodermia variabilis',
#  'erythromelalgia',
#  'erythroplakia oral',
#  'erythropoietic protoporphyria',
#  'essential fatty acid deficiency',
#  'excoriations neurotic',
#  'exostoses oral',
#  'fabrys disease',
#  'familial mediterranean fever',
#  'familial partial lipodystrophy',
#  'farbers lipogranulomatosis',
#  'fasciitis necrotizing',
#  'fascioliasis',
#  'favre and racouchot disease',
#  'felon',
#  'fetal hydantoin syndrome',
#  'fibroblastic rheumatism',
#  'fibroepithelioma of pinkus',
#  'fibrokeratoma acquired digital',
#  'fibroma oral',
#  'fibroma peripheral ossifying',
#  'fibrosarcoma',
#  'fibrous hamartoma of infant',
#  'fibrous histiocytoma malignant',
#  'fibrous papule of nose',
#  'filariasis',
#  'fire ant sting',
#  'flea bite',
#  'focal acral hyperkeratosis',
#  'focal dermal hypoplasia',
#  'folliculitis',
#  'folliculitis pityrosporum',
#  'folliculitis pseudomonas',
#  'fordyce spots',
#  'foreign body granuloma',
#  'foxfordyce disease',
#  'franceschettijadassohn syndrome',
#  'frostbite',
#  'furunculosis',
#  'fusarium infection disseminated',
#  'futcher lines',
#  'galactorrhea',
#  'ganglion cyst',
#  'gardner syndrome',
#  'gas gangrene',
#  'generalized essential telangiectasia',
#  'gianotticrosti syndrome',
#  'giant cell tumor of tendon sheath',
#  'giardiasis',
#  'gingival hyperplasia',
#  'gingivitis desquamative',
#  'glanders',
#  'glomangiomas',
#  'glomeruloid hemangioma',
#  'glomus tumor',
#  'glossitis migratory',
#  'glucagonoma syndrome',
#  'gnathostomiasis',
#  'goldenhar syndrome',
#  'gonorrhea primary infection',
#  'gout',
#  'graftversushost disease acute',
#  'graftversushost disease chronic',
#  'granular cell tumor',
#  'granuloma annulare',
#  'granuloma faciale',
#  'granuloma fissuratum cutaneous',
#  'granuloma gluteale infantum',
#  'granuloma inguinale',
#  'granuloma peripheral giant cell',
#  'gynecomastia',
#  'haileyhailey disease',
#  'hairdressers nails',
#  'hairy leukoplakia oral',
#  'hairy tongue',
#  'half and half nail syndrome',
#  'halo nevus',
#  'halo scalp ring',
#  'hamartoma smooth muscle',
#  'hand dermatitis',
#  'handfootandmouth disease',
#  'hantavirus pulmonary syndrome',
#  'harlequin fetus',
#  'heel fissure',
#  'hemangioma infantile',
#  'hemangioma oral',
#  'hemangiomatosis diffuse neonatal',
#  'hemangiopericytoma',
#  'hemochromatosis',
#  'hemophagocytic lymphohistiocytosis',
#  'henochschnlein purpura',
#  'heparin necrosis',
#  'hepatitis a virus',
#  'hereditary acrodermatitis enteropathica',
#  'hereditary hemorrhagic telangiectasia',
#  'hermanskypudlak syndrome',
#  'herpangina',
#  'herpes gestationis',
#  'herpes simplex virus',
#  'herpes simplex virus disseminated',
#  'herpes simplex virus genital',
#  'herpes simplex virus gladiatorum',
#  'herpes simplex virus neonatal',
#  'herpes zoster',
#  'herpetic whitlow',
#  'hibernoma',
#  'hidradenitis suppurativa',
#  'hidrotic ectodermal dysplasia',
#  'hirsutism',
#  'histiocytosis congenital selfhealing',
#  'histiocytosis langerhans cell',
#  'histoplasmosis',
#  'histoplasmosis african',
#  'hivaids related pruritus',
#  'hobo spider envenoming',
#  'hodgkins disease',
#  'homocystinuria',
#  'honeybee sting',
#  'hornet sting',
#  'howelevans syndrome',
#  'human immunodeficiency virus primary infection',
#  'hurler syndrome',
#  'hydroa vacciniforme',
#  'hypereosinophilic syndrome',
#  'hypergammaglobulinemic purpura of waldenstrom',
#  'hyperhidrosis',
#  'hyperimmunoglobulinemia d syndrome',
#  'hyperimmunoglobulinemia e syndrome',
#  'hyperkeratosis oral frictional',
#  'hyperpigmentation postinflammatory',
#  'hyperplasia denture induced',
#  'hypertrichosis',
#  'hypertrichosis lanuginosa congenita',
#  'hypomelanosis of ito',
#  'hypopigmentation postinflammatory',
#  'ichthyosiform erythroderma congenital nonbullous',
#  'ichthyosis acquired',
#  'ichthyosis vulgaris',
#  'ichthyosis xlinked',
#  'idiopathic guttate hypomelanosis',
#  'idiopathic thrombocytopenic purpura',
#  'impetigo bullous',
#  'impetigo bullous pediatric',
#  'impetigo herpetiformis',
#  'impetigo nonbullous',
#  'incontinentia pigmenti',
#  'infantile digital fibromatosis',
#  'infantile myofibromatosis',
#  'infundibulofolliculitis',
#  'ingrown toenail',
#  'injury medical procedure in utero',
#  'intertrigo',
#  'iododerma',
#  'ischemic ulcer',
#  'japanese spotted fever',
#  'jaquets erosive diaper dermatitis',
#  'jessners benign lymphocytic infiltrate',
#  'juvenile hyaline fibromatosis',
#  'juvenile idiopathic arthritis',
#  'juvenile plantar dermatosis',
#  'juvenile spring eruption',
#  'juvenile xanthogranuloma',
#  'kaposi sarcoma aidsassociated',
#  'kaposi sarcoma nonaids',
#  'kasabachmerritt syndrome',
#  'kawasaki disease',
#  'keloid',
#  'keratoacanthoma',
#  'keratoderma palmoplantar',
#  'keratolysis pitted',
#  'keratosis follicularis spinulosa decalvans',
#  'keratosis pilaris',
#  'keratosis pilaris atrophicans faciei',
#  'keratosis seborrheic',
#  'kerion',
#  'kid syndrome',
#  'kikuchifujimoto disease',
#  'kimura disease',
#  'kindler syndrome',
#  'klippeltrenaunay syndrome',
#  'knuckle pads',
#  'koilonychia',
#  'koilonychia infantile',
#  'kwashiorkor',
#  'kyasanur forest disease',
#  'kyrles disease',
#  'lamellar ichthyosis',
#  'larva migrans cutaneous',
#  'lassa fever',
#  'late congenital syphilis',
#  'leiner disease',
#  'leiomyoma',
#  'leishmaniasis mucosal',
#  'leishmaniasis new world cutaneous',
#  'leishmaniasis old world cutaneous',
#  'lentigo maligna',
#  'lentigo maligna melanoma',
#  'lentigo simplex',
#  'lentigo solar',
#  'leprosy',
#  'leptospirosis',
#  'leschnyhan syndrome',
#  'lethal midline granuloma',
#  'leukemia congenital',
#  'leukemia cutis',
#  'leukemic infiltration oral',
#  'leukoedema',
#  'leukonychia',
#  'leukoplakia',
#  'lichen amyloidosis',
#  'lichen nitidus',
#  'lichen planus',
#  'lichen planus oral',
#  'lichen sclerosus',
#  'lichen simplex chronicus',
#  'lichen spinulosus',
#  'lichen striatus',
#  'lichenoid keratosis',
#  'linea alba',
#  'linea nigra',
#  'linea nigra in newborn',
#  'linear and whorled nevoid hypermelanosis',
#  'linear epidermal nevus',
#  'linear focal elastosis',
#  'linear iga dermatosis',
#  'lipoatrophy',
#  'lipoblastoma',
#  'lipodermatosclerosis',
#  'lipodystrophy drug induced',
#  'lipogranulomatosis subcutanea of rothmann and makai',
#  'lipoma',
#  'listeriosis',
#  'livedo reticularis',
#  'livedoid vasculopathy',
#  'lizard envenoming',
#  'lobomycosis',
#  'loiasis',
#  'longitudinal melanonychia',
#  'longitudinal nail ridging',
#  'lumbosacral infantile hemangioma',
#  'lumbosacral skin lesion',
#  'lupus erythematosus discoid',
#  'lupus erythematosus drug induced',
#  'lupus erythematosus neonatal',
#  'lupus erythematosus subacute cutaneous',
#  'lupus erythematosus systemic',
#  'lupus erythematosus tumid',
#  'lupus miliaris disseminatus faciei',
#  'lupus panniculitis',
#  'lyme disease',
#  'lymphangioma circumscriptum',
#  'lymphangioma oral',
#  'lymphangiosarcoma',
#  'lymphangitis',
#  'lymphedema',
#  'lymphogranuloma venereum',
#  'lymphoma',
#  'lymphoma cutaneous bcell',
#  'lymphoma nonhodgkins',
#  'lymphomatoid papulosis',
#  'macular amyloidosis',
#  'maffucci syndrome',
#  'majocchis granuloma',
#  'malaria',
#  'malignant atrophic papulosis',
#  'malignant otitis externa',
#  'marasmus',
#  'marburg filoviridae virus infection',
#  'marfan syndrome',
#  'mastocytoma',
#  'mccunealbright syndrome',
#  'median nail dystrophy',
#  'median raphe cyst of penis',
#  'median rhomboid glossitis',
#  'mediterranean spotted fever',
#  'megalencephalycapillary malformationpolymicrogyria syndrome',
#  'melanoacanthoma oral',
#  'melanoma',
#  'melanoma acral lentiginous',
#  'melanotic macule oral',
#  'melasma',
#  'melioidosis',
#  'melkerssonrosenthal syndrome',
#  'meningococcemia acute',
#  'meningococcemia chronic',
#  'merkel cell carcinoma',
#  'michelin tire baby syndrome',
#  'microcystic adnexal carcinoma',
#  'micronychia congenital',
#  'microvenular hemangioma',
#  'middle east respiratory syndrome coronavirus',
#  'milia',
#  'miliaria crystallina',
#  'miliaria rubra',
#  'milkers nodules',
#  'millipede dermatitis',
#  'mite dermatitis',
#  'mixed toe web infection',
#  'molluscum contagiosum',
#  'molluscum contagiosum pediatric',
#  'monkeypox',
#  'mononucleosis',
#  'morphea',
#  'mucocele oral',
#  'mucormycosis',
#  'mucosal pigmentation multifocal or diffuse',
#  'muirtorre syndrome',
#  'multicentric reticulohistiocytosis',
#  'multinucleate cell angiohistiocytoma',
#  'multiple carboxylase deficiency',
#  'multiple endocrine neoplasia type ',
#  'multiple lentigines syndrome',
#  'multiple myeloma',
#  'mumps',
#  'mycobacterium aviumintracellulare infection',
#  'mycobacterium chelonae infection',
#  'mycobacterium marinum infection',
#  'mycoplasma exanthem',
#  'myiasis',
#  'myxoid cyst',
#  'nail biting',
#  'nail changes of chronic renal failure',
#  'nail changes pesticide induced',
#  'nail polish damage',
#  'nailpatellaelbow syndrome',
#  'necrobiosis lipoidica',
#  'necrobiotic xanthogranuloma',
#  'neonatal bacterial sepsis',
#  'neonatal pustular dermatosis transient',
#  'nephrogenic fibrosing dermopathy',
#  'netherton syndrome',
#  'neurilemmoma',
#  'neuroblastoma congenital',
#  'neurofibroma solitary',
#  'neurofibromatosis',
#  'neurogenic ulcer',
#  'neurothekeoma',
#  'neutrophilic eccrine hidradenitis',
#  'nevus agminated',
#  'nevus anemicus',
#  'nevus atypical',
#  'nevus beckers',
#  'nevus blue',
#  'nevus comedonicus',
#  'nevus common acquired',
#  'nevus congenital melanocytic',
#  'nevus depigmentosus',
#  'nevus lipomatosus superficialis',
#  'nevus of ito',
#  'nevus of ota',
#  'nevus sebaceus',
#  'nipah virus infection',
#  'nocardiosis',
#  'nodular amyloidosis',
#  'noonan syndrome',
#  'notalgia paresthetica',
#  'ochronosis exogenous',
#  'omphalitis of the newborn',
#  'omphalocele',
#  'omsk hemorrhagic fever',
#  'onchocerciasis',
#  'onychodysplasia congenital',
#  'onychogryphosis',
#  'onycholysis',
#  'onychomadesis',
#  'onychomycosis',
#  'onychomycosis proximal subungual',
#  'onychomycosis superficial white',
#  'onychoschizia',
#  'onychotillomania habit tic deformity',
#  'oral lupus erythematosus',
#  'oralfacialdigital syndrome',
#  'orf',
#  'orofacial granulomatosis',
#  'orofacial herpes simplex virus',
#  'osteogenesis imperfecta',
#  'osteoma cutis',
#  'osteomyelitis',
#  'pachydermoperiostosis',
#  'pachyonychia congenita',
#  'paederus dermatitis',
#  'pagets disease extramammary',
#  'palmar xanthomas',
#  'pancreatic panniculitis',
#  'papilloma oral',
#  'papular mucinosis',
#  'papularpurpuric gloves and socks syndrome',
#  'paracoccidioidomycosis',
#  'paragonimiasis',
#  'parakeratosis pustulosa',
#  'parapsoriasis large plaque',
#  'parapsoriasis small plaque',
#  'paronychia bacterial',
#  'paronychia candidal',
#  'paronychia candidal pediatric',
#  'paronychia chronic',
#  'paronychia drug induced',
#  'parry romberg disease',
#  'pasteurella multocida infection',
#  'pediculosis capitis',
#  'pediculosis corporis',
#  'pediculosis pubis',
#  'pellagra',
#  'pemphigus erythematosus',
#  'pemphigus foliaceus',
#  'pemphigus paraneoplastic',
#  'pemphigus vegetans',
#  'pemphigus vulgaris',
#  'penicillium marneffei',
#  'perforating folliculitis',
#  'perianal streptococcal infection',
#  'periungual fibroma',
#  'peutzjeghers syndrome',
#  'phace syndrome',
#  'photoonycholysis',
#  'phrynoderma',
#  'phytophotodermatitis',
#  'piebaldism',
#  'piezogenic pedal papules',
#  'pilar cyst',
#  'pilomatricoma',
#  'pilonidal abscess',
#  'pincer nail deformity',
#  'pit viper snake envenoming',
#  'pityriasis alba',
#  'pityriasis lichenoides chronica',
#  'pityriasis lichenoides et varioliformis acuta',
#  'pityriasis rosea',
#  'pityriasis rubra pilaris',
#  'pityriasis rubra pilaris juvenile',
#  'plague bubonic',
#  'plague pneumonic',
#  'plane xanthomas',
#  'plummervinson syndrome',
#  'podoconiosis',
#  'poems syndrome',
#  'poikiloderma of civatte',
#  'poikiloderma vasculare atrophicans',
#  'polyarteritis nodosa',
#  'polymorphous light eruption',
#  'polymyalgia rheumatica',
#  'porokeratosis',
#  'porokeratotic eccrine ostial and dermal duct nevus',
#  'porphyria cutanea tarda',
#  'portwine stain',
#  'postmaturity desquamation',
#  'preauricular sinus',
#  'pressure ulcer',
#  'pressure urticaria',
#  'pretibial myxedema',
#  'progeria',
#  'progressive bacterial synergistic gangrene',
#  'proliferative verrucous leukoplakia',
#  'proteus syndrome',
#  'protothecosis',
#  'prurigo nodularis',
#  'pruritic urticarial papules and plaques of pregnancy',
#  'pruritus ani',
#  'pruritus of the elderly',
#  'pruritus without rash',
#  'pseudocyst of auricle',
#  'pseudofolliculitis barbae',
#  'pseudolymphoma',
#  'pseudomonas nail infection',
#  'pseudoporphyria',
#  'pseudoxanthoma elasticum',
#  'psittacosis',
#  'psoriasis',
#  'psoriasis erythrodermic',
#  'psoriasis guttate',
#  'psoriasis infantile',
#  'psoriasis pustular',
#  'pterygium nail',
#  'purpura fulminans',
#  'purpura traumatic',
#  'puss caterpillar sting',
#  'pustulosis palmoplantar',
#  'pyoderma faciale',
#  'pyoderma gangrenosum',
#  'pyogenic granuloma',
#  'pyostomatitis vegetans',
#  'pyramidal perianal papule',
#  'q fever',
#  'queensland tick typhus',
#  'radiation dermatitis',
#  'ramsayhunt syndrome',
#  'ranula',
#  'ratbite fever streptobacillus moniliformis',
#  'raynauds phenomenon',
#  'reactive arthritis',
#  'reactive perforating collagenosis',
#  'recluse spider envenoming',
#  'relapsing polychondritis',
#  'restrictive dermopathy',
#  'reticular erythematous mucinosis',
#  'reticulate pigmented anomaly of flexures',
#  'rheumatoid arthritis',
#  'rheumatoid nodule',
#  'richnerhanhart syndrome',
#  'rickettsialpox',
#  'riehls melanosis',
#  'rift valley fever',
#  'rocky mountain spotted fever',
#  'rosacea',
#  'roseola',
#  'rothmundthomson syndrome',
#  'rubella',
#  'rubella congenital',
#  'rubeola',
#  'sacral dimple',
#  'salivary gland tumor benign',
#  'salivary gland tumor malignant',
#  'salmon patch',
#  'sarcoidosis',
#  'sars',
#  'scabies',
#  'scabies crusted',
#  'scabies pediatric',
#  'scar',
#  'scarlet fever',
#  'schistosomiasis',
#  'scleredema',
#  'scleroderma',
#  'scleroderma of childhood',
#  'scombroid fish poisoning',
#  'scopulariopsis',
#  'scorpion sting',
#  'scurvy',
#  'seabathers eruption',
#  'sebaceous adenoma',
#  'sebaceous hyperplasia',
#  'sebaceous hyperplasia in newborn',
#  'segmental neurofibromatosis',
#  'sepsis bacterial',
#  'serum sickness',
#  'serum sicknesslike reaction',
#  'severe combined immunodeficiency',
#  'sialometaplasia necrotizing',
#  'sickle cell anemia',
#  'sinus histiocytosis',
#  'sjgren syndrome',
#  'sjgrenlarsson syndrome',
#  'smallpox',
#  'sneddon syndrome',
#  'sneddonwilkinson subcorneal pustulosis',
#  'solar elastosis',
#  'solar purpura',
#  'south american hemorrhagic fever',
#  'southern tickassociated rash illness',
#  'speckled lentiginous nevus',
#  'spider angioma',
#  'spitz nevus',
#  'sporotrichosis',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma oral',
#  'staphylococcal scalded skin syndrome',
#  'steatocystoma multiplex',
#  'stevensjohnson syndrome',
#  'sting jellyfish',
#  'stomatitis contact',
#  'stomatitis nicotine',
#  'streptococcal pharyngitis',
#  'striae',
#  'strongyloidiasis',
#  'stucco keratosis',
#  'sturgeweber syndrome',
#  'subcutaneous fat necrosis of the newborn',
#  'substance abuse skin popping',
#  'subungual exostosis',
#  'subungual fibroma',
#  'subungual hematoma',
#  'sucking callusblister',
#  'sunburn',
#  'supernumerary nipple',
#  'sweets syndrome',
#  'symmetrical lividity of the palms or soles',
#  'syphilis congenital',
#  'syphilis endemic',
#  'syphilis primary',
#  'syphilis secondary',
#  'syphilis tertiary',
#  'syringoma',
#  'takayasu arteritis',
#  'talon noir',
#  'tanapox',
#  'tarantula envenoming',
#  'telangiectasia',
#  'telangiectasia macularis eruptiva perstans',
#  'telogen effluvium',
#  'terra firmaforme dermatosis',
#  'terrys nails',
#  'thrombocytopenic purpura newborn',
#  'thrombotic thrombocytopenic purpura',
#  'thyroglossal duct cyst',
#  'thyroid acropachy',
#  'tick bite',
#  'tinea barbae',
#  'tinea capitis',
#  'tinea corporis',
#  'tinea cruris',
#  'tinea faciei',
#  'tinea nigra',
#  'tinea pedis',
#  'tinea versicolor',
#  'tnf receptorassociated periodic syndrome',
#  'tobacco staining of nails',
#  'tongue fissured',
#  'torus mandibularis',
#  'torus palatinus',
#  'toxic epidermal necrolysis',
#  'toxic shock syndrome',
#  'toxocariasis',
#  'transient acantholytic dermatosis',
#  'transient bullous dermolysis of the newborn',
#  'trauma bulla',
#  'traumatic eosinophilic granuloma',
#  'trench fever',
#  'trichilemmoma',
#  'trichinellosis',
#  'trichodiscoma',
#  'trichoepithelioma',
#  'trichomycosis axillaris',
#  'trichorrhexis nodosa',
#  'trichosporon beigelii sepsis',
#  'trichothiodystrophy',
#  'trigeminal trophic syndrome',
#  'trypanosomiasis african',
#  'trypanosomiasis american',
#  'tuberculosis cutaneous',
#  'tuberous sclerosis',
#  'tufted angioma',
#  'tularemia',
#  'tungiasis',
#  'turner syndrome',
#  'twentynail dystrophy',
#  'typhoid fever',
#  'typhus endemic',
#  'typhus epidemic',
#  'typhus scrub',
#  ...]
